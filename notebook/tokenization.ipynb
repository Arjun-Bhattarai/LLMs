# %%
# file open garera text read garna ko lagi
with open(
    r"C:\Users\Acer\Documents\LLMs\LLMs\data\the-verdict.txt", encoding="utf-8"
) as f:
    raw_data = f.read()

# total character count dekhauna
print("total characters:", len(raw_data))

# first 100 characters print garna
print(raw_data[:100])
# Out:
# total characters: 20479
# I HAD always thought Jack Gisburn rather a cheap genius--though a good fellow enough--so it was no g

# %%
import re

preprocess = re.split(r'([,.:;!?()\-\[\]"\'/@#$%^&*_+=<>|{}~`\\\n\t]+)', raw_data)
preprocess = [item for item in preprocess if item]
print(preprocess[:30])
# Out:
# ['I HAD always thought Jack Gisburn rather a cheap genius', '--', 'though a good fellow enough', '--', 'so it was no great surprise to me to hear that', ',', ' in the height of his glory', ',', ' he had dropped his painting', ',', ' married a rich widow', ',', ' and established himself in a villa on the Riviera', '.', ' ', '(', 'Though I rather thought it would have been Rome or Florence', '.)\n\n"', 'The height of his glory', '"--', 'that was what the women called it', '.', ' I can hear Mrs', '.', ' Gideon Thwing', '--', 'his last Chicago sitter', '--', 'deploring his unaccountable abdication', '.']

# %%
# unique words ko list banauna lai
text_data = raw_data.lower()
text_data = re.sub(r"[^\w\s]", "", text_data)
preprocess = text_data.split()

all_words = sorted(set(preprocess))

vocab = {word: i for i, word in enumerate(all_words)}
vocab["<UNK>"] = len(vocab)

print("vocab size:", len(vocab))
# Out:
# vocab size: 1153

# %%
# word lai integer ma convert garne and short ma print garne
vocab = {token: i for i, token in enumerate(all_words)}

# unknown token add garna
vocab["<UNK>"] = len(vocab)
# vocab size update garna
print("vocab size:", len(vocab))
print("sample vocab items:", list(vocab.items())[:10])
# Out:
# vocab size: 1153
# sample vocab items: [('_am_', 0), ('_familleverte_', 1), ('_felt_', 2), ('_has_', 3), ('_have_', 4), ('_jardiniere_', 5), ('_mine_oh', 6), ('_not_', 7), ('_rose', 8), ('_rs_', 9)]

# %%
# vocab ko first 50 items print garna
for i, item in enumerate(vocab.items()):
    print(item)

    if i > 50:
        break
# Out:
# ('_am_', 0)
# ('_familleverte_', 1)
# ('_felt_', 2)
# ('_has_', 3)
# ('_have_', 4)
# ('_jardiniere_', 5)
# ('_mine_oh', 6)
# ('_not_', 7)
# ('_rose', 8)
# ('_rs_', 9)
# ('_that_', 10)
# ('_that_it', 11)
# ('_the_', 12)
# ('_was_', 13)
# ('_were_', 14)
# ('a', 15)
# ('abdication', 16)
# ('able', 17)
# ('about', 18)
# ('above', 19)
# ('abruptly', 20)
# ('absolute', 21)
# ('absorbed', 22)
# ('absurdity', 23)
# ('academic', 24)
# ('accuse', 25)
# ('accustomed', 26)
# ('across', 27)
# ('activity', 28)
# ('add', 29)
# ('added', 30)
# ('admirers', 31)
# ('adopted', 32)
# ('adulation', 33)
# ('advance', 34)
# ('aesthetic', 35)
# ('affect', 36)
# ('afraid', 37)
# ('after', 38)
# ('afterward', 39)
# ('again', 40)
# ('againwhat', 41)
# ('ago', 42)
# ('ah', 43)
# ('ahi', 44)
# ('air', 45)
# ('alive', 46)
# ('all', 47)
# ('allas', 48)
# ('almost', 49)
# ('alone', 50)
# ('along', 51)

# %%
class Tokenizer:
    def __init__(self, vocab):
        self.str_to_int = vocab
        self.int_to_str = {i: s for s, i in vocab.items()}

    # token lai integer ma convert garne
    def encode(self, text):
        text = text.lower()
        text = re.sub(r"[^\w\s]", "", text)
        tokens = text.split()

        return [
            (
                self.str_to_int[token]
                if token in self.str_to_int
                else self.str_to_int["<UNK>"]
            )
            for token in tokens
        ]

    # id lai text ma convert garne
    def decode(self, ids):
        text = " ".join([self.int_to_str[i] for i in ids])
        return text

# %%
# token lai integer ma convert garne tokenizer class banauna
tokenizer = Tokenizer(vocab)

text = "I felt to what a degree he had the same quality as his pictures."
ids = tokenizer.encode(text)
print("encoded ids:", ids)
# Out:
# encoded ids: [504, 354, 1020, 1103, 15, 233, 463, 443, 985, 841, 794, 80, 488, 751]

# %%
tokenizer.decode(ids)
# Out:
# 'i felt to what a degree he had the same quality as his pictures'

# %%
print("total tokens:", len(preprocess))
# Out:
# total tokens: 3613

# %%
# file ko path print garna
import os

print(os.getcwd())
# Out:
# C:\Users\Acer\Documents\LLMs\LLMs

# %%
# word lai token ma split garna ko lagi
import re

text = "hello, world! how-are you?"

# comma, space, !, ?, - jasta symbols bata split garera words banaune
tokens = re.split(r"[ ,!?-]+", text)


print(tokens)
# Out:
# ['hello', 'world', 'how', 'are', 'you', '']

# %%
import re

text = "hello, world! how-are you?"

tokens = re.split(r"[ ,!?-]+", text)
# empty string tokens hataune
tokens = [item for item in tokens if item]

print(tokens)
# Out:
# ['hello', 'world', 'how', 'are', 'you']
